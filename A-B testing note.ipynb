# %% [markdown]
# # Lesson1 note

# %% [markdown]
# 1. choose a metric
# 2. review statistic
# 3. design
# 4. analyze

# %% [markdown]
# ab testing is
# 1.not good at testing long term feedback. eg:house rental website referral
# 2.cannot tell you if you miss something.
#
# 有对照组很重要
#
# examples are not good using a/b testing:
# 1 change brand logo (huge emotion change and a/b is short)
# 2 house rental website referral
# 3.add premium service (need to gather more information)

# %% [markdown]
# ![Screen%20Shot%202018-12-16%20at%204.17.52%20PM.png](attachment:Screen%20Shot%202018-12-16%20at%204.17.52%20PM.png)

# %% [markdown]
# ctf= click through rate
# number of click/number of page view
# using for measuring the use bility of a button 例如：这个button是不是要换个颜色
#
# ctp = click through probability
# unique visitors who click/unique vistors to page
# using for measuring who goes to next page 例如：到底有多少个人到了下个页面

# %% [markdown]
# # binomial distribution

# %% [markdown]
# 1. two situations. 两种情况
# 2. independent
# 3. identical distribution (P is always the same)

# %% [markdown]
# ## how to calculate the confidence interval
# ![Screen%20Shot%202018-12-16%20at%208.57.17%20PM.png] <img src="attachment:Screen%20Shot%202018-12-16%20at%208.57.17%20PM.png" width="400">
#
# ![Screen%20Shot%202018-12-16%20at%208.56.39%20PM.png] <img src="attachment:Screen%20Shot%202018-12-16%20at%208.56.39%20PM.png" width="400">

# %% [markdown]
# ## Hypothesis testing
